# %% [markdown]
# *1*

# %%
planets=["Mercury", "Venus", "Earth"]
print(planets)
# Out:
# ['Mercury', 'Venus', 'Earth']

# %% [markdown]
# *2*

# %%
planets=["Mercury", "Venus", "Earth"]
print(planets[1])
# Out:
# Venus

# %% [markdown]
# *3*

# %%
planets=["Mercury", "Venus", "Earth"]
planets.append("Mars")
print(planets)
# Out:
# ['Mercury', 'Venus', 'Earth', 'Mars']

# %% [markdown]
# *4*

# %%
moons=["Moon","Phobos", "Deimos"]
print(len(moons))
# Out:
# 3

# %% [markdown]
# *5*

# %%
Sun={
    "name": "Sun"
}
print(Sun["name"])
# Out:
# Sun

# %% [markdown]
# *6*

# %%
star_info={
    'name': "Sirius",
    'color': "Blue-White"
}
print(star_info["color"])
# Out:
# Blue-White

# %% [markdown]
# *7*

# %%
star_info={
    'name': "Sirius",
    'color': "Blue-WHite"
}
star_info["distance"] = 8.6
print(star_info)
# Out:
# {'name': 'Sirius', 'color': 'Blue-WHite', 'distance': 8.6}

# %% [markdown]
# *8*

# %%
galaxy_info={
    'name':"Andromeda",
    'type':"Spiral"
}
print(galaxy_info.keys())
# Out:
# dict_keys(['name', 'type'])

# %% [markdown]
# *9*

# %%
Astronaut=(1961, "Gagarin")
print(f"{Astronaut[0]} & {Astronaut[1]}")
# Out:
# 1961 & Gagarin

# %% [markdown]
# *10*

# %%
moon_info=(1969, "Armstrong")
print(moon_info[0])
# Out:
# 1969

# %% [markdown]
# *11*

# %% [markdown]
# *No*, tuples are immutable entities in python and cannot be changed or updated once they are created.

# %% [markdown]
# *12*

# %%
gas_giants={"Jupiter", "Saturn", "Uranus", "Neptune"}
print(gas_giants)
# Out:
# {'Jupiter', 'Neptune', 'Saturn', 'Uranus'}

# %% [markdown]
# *13*

# %%
gas_giants={"Jupiter", "Saturn", "Uranus", "Neptune"}
if "Earth" in gas_giants:
    print("Earth is present in the set.")
else:
    print("Earth is not in the set.")
# Out:
# Earth is not in the set.

# %% [markdown]
# *14*

# %%
gas_giants={"Jupiter", "Saturn"}
gas_giants.add("Jupiter")
print(gas_giants)
# Out:
# {'Saturn', 'Jupiter'}

# %% [markdown]
# If I add the element "Jupiter" once again the set, then the set will remain unchanged, because in a set one element is taken into account only once.

# %% [markdown]
# *15*

# %%
observed = ["Moon", "Mars", "Moon", "Jupiter", "Mars"]
unique_observations = set(observed)
print(unique_observations)
# Out:
# {'Moon', 'Jupiter', 'Mars'}
