# %% [markdown]
# **1**

# %%
Details_Galaxy = "Andromeda-Spiral Galaxy"
print(Details_Galaxy)
# Out:
# Andromeda-Spiral Galaxy

# %% [markdown]
# **2**

# %%
Details_Galaxy = "Andromeda-Spiral Galaxy"
Details_Galaxy_Uppercase =Details_Galaxy.upper()
print(Details_Galaxy_Uppercase)
# Out:
# ANDROMEDA-SPIRAL GALAXY

# %% [markdown]
# **3**

# %%
Details_Galaxy = "Andromeda-Spiral Galaxy"
Details_Galaxy_Split = Details_Galaxy.split("-")
Object_Type = Details_Galaxy_Split[1]
print(Object_Type)
# Out:
# Spiral Galaxy

# %% [markdown]
# **4**

# %%
name = "Andromeda"
description = "a spiral galaxy"
formatted = f"{name} is {description}"
print(formatted)
# Out:
# Andromeda is a spiral galaxy

# %% [markdown]
# **5**

# %%
object_name = "Crab Nebula"
description = " is a supernova remnant"

result = object_name + description

print(result)
# Out:
# Crab Nebula is a supernova remnant

# %% [markdown]
# **6**

# %%
Star_Coordinates = "RA: 05h 34m 31.94s, Dec: +22° 00′ 52.2″"
Star_Coordinates_Split = Star_Coordinates.split(",")
RA = Star_Coordinates_Split[0].split(":")[1].strip()
Dec = Star_Coordinates_Split[1].split(":")[1].strip()
print("Right Ascension:", RA)
print("Declination:", Dec)
# Out:
# Right Ascension: 05h 34m 31.94s
# Declination: +22° 00′ 52.2″

# %% [markdown]
# **7**

# %%
Warning_Message = "Extra-terrestrial life detected!"*30
print(Warning_Message)
# Out:
# Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!Extra-terrestrial life detected!

# %% [markdown]
# **8**

# %%
galaxy = ["Milky Way", " is a ", "Spiral Galaxy"]
Sentence = "".join(galaxy)
print(Sentence)
# Out:
# Milky Way is a Spiral Galaxy

# %% [markdown]
# **9**

# %%
Astro_description = "Sun is a star"
position =Astro_description.find("star")
print("\"star\" found at index:", position)
# Out:
# "star" found at index: 9

# %% [markdown]
# **10**

# %%
Astro_description = "Sun is a star"
Occurence_Count_Sun = Astro_description.count("Sun")
print("The word \"Sun\" occurs", Occurence_Count_Sun, "time(s).")
# Out:
# The word "Sun" occurs 1 time(s).

# %% [markdown]
# **11**

# %%
object_info = "Vega-Main Sequence"
object_info_split = object_info.split("-")

Object_Name = object_info_split[0]
Object_Type = object_info_split[1]

table_name = "Stars"

SQL_Query = f"SELECT * FROM {table_name} WHERE name = '{Object_Name}' AND type = '{Object_Type}';"

print(SQL_Query)
# Out:
# SELECT * FROM Stars WHERE name = 'Vega' AND type = 'Main Sequence';
