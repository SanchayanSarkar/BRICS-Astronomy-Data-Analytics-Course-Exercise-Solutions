# %% [markdown]
# >**_Variables_**

# %% [markdown]
# **Question 1**

# %%
planet_name="Jupiter"
planet_name
# Out:
# 'Jupiter'

# %% [markdown]
# **Question 2**

# %%
distance_to_sun=149.6
distance_to_sun
# Out:
# 149.6

# %% [markdown]
# **Question 3**

# %%
star_temp=5500
star_temp+=500
star_temp
# Out:
# 6000

# %% [markdown]
# _alternatively you can perform:_

# %%
star_temp=5500
star_temp=6000 #star_temp is now having a reassigned value of 6000
star_temp
# Out:
# 6000

# %% [markdown]
# **Question 4**

# %%
is_gas_giant=True
if is_gas_giant:
    print("Jupiter is a gas giant.")
else:
    print("Code is wrong.") #assigns value true to the required variable name and then to check whether your code is correct or not we use a if-else to print: Jupiter is a gas giant if the code is correct and print: Code is wrong, in case the solution is wrong.
# Out:
# Jupiter is a gas giant.

# %% [markdown]
# **Question 5**

# %%
moon_count=2 #define the variable
print(f"Mars has {moon_count} moons.")
#Introduced in Python 3.6, f-strings provide a clean way to inject variables or logic directly into strings by adding an f prefix. By wrapping expressions in {} braces, you can perform math, call functions, or display variables instantly, making your code much easier to read and write.
# Out:
# Mars has 2 moons.

# %% [markdown]
# **Question 6**

# %% [markdown]
# Using spaces in a variable name like 'Number Of Stars'; is invalid because Python reads the first space as the end of the identifier. This breaks the code because the interpreter expects an assignment operator immediately after the name, leading to a SyntaxError.

# %% [markdown]
# >**_Operators_**

# %% [markdown]
# **Question 1**

# %%
Earth_Sun_Distance=1.0
Mars_Sun_Distance=1.52
Difference=Mars_Sun_Distance-Earth_Sun_Distance
print(Difference)
# Out:
# 0.52

# %% [markdown]
# **Question 2**

# %%
Earth_year=365.25 #days
Jupiter_year=11.86*Earth_year
print(Jupiter_year)
# Out:
# 4331.865

# %% [markdown]
# **Question 3**

# %%
jupiter_moons=79
jupiter_moons+=3
print(jupiter_moons)
# Out:
# 82

# %% [markdown]
# **Question 4**

# %%
Venus_temp=462
Earth_temp=15
Venus_temp>Earth_temp #shows whether the comparision is true or not
# Out:
# True

# %% [markdown]
# **Question 5**

# %%
galaxy_type="Spiral"
galaxy_type=="Elliptical" #shows whether the value is exactly equal or not by telling true or false
# Out:
# False

# %% [markdown]
# **Question 6**

# %%
has_water=True
atmosphere_ok=False
habitable_planet=has_water and atmosphere_ok
habitable_planet
# Out:
# False

# %% [markdown]
# **Question 7**

# %%
is_night=True
is_solar_telescope=False
Observing_Possible= is_night or is_solar_telescope
Observing_Possible
# Out:
# True

# %% [markdown]
# **Question 8**

# %%
distance_ly=4.24
km_per_ly=9.461e12
distance_km=4.24*9.461e12
print(distance_km)
# Out:
# 40114640000000.0
